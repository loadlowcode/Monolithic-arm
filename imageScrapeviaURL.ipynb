# %%
from google.colab import drive
import requests
from bs4 import BeautifulSoup
import os
from urllib.parse import urljoin, urlparse
from google.colab import drive

drive.mount('/content/drive')

def download_images(url, folder_path):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    img_tags = soup.find_all('img')
    img_urls = [img['src'] for img in img_tags if 'src' in img.attrs]

    for img_url in img_urls:
        img_url = urljoin(url, img_url)
        img_name = os.path.basename(urlparse(img_url).path)
        img_path = os.path.join(folder_path, img_name)

        with open(img_path, 'wb') as img_file:
            img_file.write(requests.get(img_url).content)

if __name__ == '__main__':
    drive.mount('/content/drive')
    url = input("Enter the URL to scrape images from: ")
    folder_path = '/content/drive/MyDrive/scraped_images'  # Change the path as needed

    # Create the folder if it doesn't exist
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)
        print(f"Created folder: {folder_path}")

    download_images(url, folder_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Enter the URL to scrape images from: https://buffer.com/library/free-images/
# Created folder: /content/drive/MyDrive/scraped_images
